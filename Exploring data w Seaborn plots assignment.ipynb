# %% [markdown]
# Assignments
# The best way to learn plotting is to make a lot of plots. To complete the following you may need to explore the seaborn documentation.
#
# 1. Find a dataset you'd like to explore. This can be something you're familiar with or something new. Create a Jupyter notebook and then:
#
# Choose one variable and plot that variable four different ways.
#
# Choose two continuous variables, and plot them three different ways.
#
# Choose one continuous variable and one categorical variable, and plot them six different ways.
#
# Give the pros and cons of each plot you create. You can use variables from multiple datasets if you like.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Loading an example dataset provided by the seaborn package.
ti = sns.load_dataset("titanic")
ti.head(12)
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %%
ti.head(n=4)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False

# %%
# Total missing values for each feature
print (ti.isnull().sum())
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
sns.distplot(ti['fare'], kde=False)

# %% [markdown]
# **Pros** : simple and easy to plot and visualize
# **Cons** : nothing to compare fare data with

# %%
sns.boxplot(y=ti['fare'])

# %% [markdown]
# Pros:
#
# Cons:

# %%
sns.rugplot(ti['fare'])

# %% [markdown]
# Pros:
#
# Cons:

# %%
sns.kdeplot(ti['fare'])

# %% [markdown]
# Pros:
#
# Cons:

# %%
sns.scatterplot(ti.age, ti.fare)

# %% [markdown]
# Pros:
#
# Cons:

# %%
sns.jointplot(ti.age, ti.fare, kind="reg")

# %% [markdown]
# Pros:
#
# Cons:

# %%
sns.stripplot(ti.age, ti.fare)

# %% [markdown]
# Pros:
#
# Cons:

# %%
sns.boxplot(ti.sex, ti.age, hue = ti.pclass)

# %% [markdown]
# Pros:
#
# Cons:

# %%
sns.countplot(x = ti.sex, data = ti)

# %% [markdown]
# Pros:
#
# Cons:

# %%
sns.violinplot(x="sex", y="age", data=ti,hue='survived',split=True,palette='rainbow')

# %% [markdown]
# Pros:
#
# Cons:

# %%
sns.stripplot(x="sex", y="age", data=ti, hue = 'survived',dodge=True)

# %% [markdown]
# Pros:
#
# Cons:

# %%
sns.swarmplot(x="sex", y="age", data=ti, hue = 'survived', dodge = True)

# %% [markdown]
# Pros:
#
# Cons:

# %%
sns.factorplot(x="sex", y="age", data=ti, hue = 'survived', kind = 'bar')

# %% [markdown]
# Pros:
#
# Cons:

# %% [markdown]
# 2.Find a dataset with at least four continuous variables and one categorical variable. Create one master plot that gives insight into the variables and their interrelationships, including:
#
# Probability distributions
#
# Bivariate relationships
#
# Whether the distributions or the relationships vary across groups
#
# Accompany your plot with a written description of what you see.
#
# When you've completed these exercises, share your results with your mentor.

# %%
mpg = sns.load_dataset("mpg")
mpg.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
mpg['cylinders'].unique()
# Out:
# array([8, 4, 6, 3, 5])

# %%
mpg['model_year'].unique()
# Out:
# array([70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82])

# %%
mpg['mpg'].unique()
# Out:
# array([18. , 15. , 16. , 17. , 14. , 24. , 22. , 21. , 27. , 26. , 25. ,
#        10. , 11. ,  9. , 28. , 19. , 12. , 13. , 23. , 30. , 31. , 35. ,
#        20. , 29. , 32. , 33. , 17.5, 15.5, 14.5, 22.5, 24.5, 18.5, 29.5,
#        26.5, 16.5, 31.5, 36. , 25.5, 33.5, 20.5, 30.5, 21.5, 43.1, 36.1,
#        32.8, 39.4, 19.9, 19.4, 20.2, 19.2, 25.1, 20.6, 20.8, 18.6, 18.1,
#        17.7, 27.5, 27.2, 30.9, 21.1, 23.2, 23.8, 23.9, 20.3, 21.6, 16.2,
#        19.8, 22.3, 17.6, 18.2, 16.9, 31.9, 34.1, 35.7, 27.4, 25.4, 34.2,
#        34.5, 31.8, 37.3, 28.4, 28.8, 26.8, 41.5, 38.1, 32.1, 37.2, 26.4,
#        24.3, 19.1, 34.3, 29.8, 31.3, 37. , 32.2, 46.6, 27.9, 40.8, 44.3,
#        43.4, 36.4, 44.6, 40.9, 33.8, 32.7, 23.7, 23.6, 32.4, 26.6, 25.8,
#        23.5, 39.1, 39. , 35.1, 32.3, 37.7, 34.7, 34.4, 29.9, 33.7, 32.9,
#        31.6, 28.1, 30.7, 24.2, 22.4, 34. , 38. , 44. ])

# %%
sns.pairplot(mpg,hue='origin',palette='rainbow', dropna = False)

# %% [markdown]
# Description:

# %%
sns.lmplot(x='model_year', y='mpg',hue='model_year', row = 'cylinders', col='origin', data=mpg,  markers="*", fit_reg = False )
plt.ylim(0,50)
# Out:
# (0, 50)

# %% [markdown]
# Description:

# %%
mpg.corr()
# Out:
#                    mpg  cylinders  displacement  horsepower    weight  \
# mpg           1.000000  -0.775396     -0.804203   -0.778427 -0.831741
# cylinders    -0.775396   1.000000      0.950721    0.842983  0.896017
# displacement -0.804203   0.950721      1.000000    0.897257  0.932824
# horsepower   -0.778427   0.842983      0.897257    1.000000  0.864538
# weight       -0.831741   0.896017      0.932824    0.864538  1.000000
# acceleration  0.420289  -0.505419     -0.543684   -0.689196 -0.417457
# model_year    0.579267  -0.348746     -0.370164   -0.416361 -0.306564
#
#               acceleration  model_year
# mpg               0.420289    0.579267
# cylinders        -0.505419   -0.348746
# displacement     -0.543684   -0.370164
# horsepower       -0.689196   -0.416361
# weight           -0.417457   -0.306564
# acceleration      1.000000    0.288137
# model_year        0.288137    1.000000

# %% [markdown]
# Description:

# %%
sns.heatmap(mpg.corr(),cmap='coolwarm')

# %% [markdown]
# Description:

# %%
tk = mpg.pivot_table(values='horsepower',index='name',columns='model_year')
sns.heatmap(tk, cmap='magma')

# %% [markdown]
# Description:

# %%
sns.distplot(mpg['mpg'])

# %% [markdown]
# Description:

# %%
g = sns.PairGrid(mpg, hue='origin',palette='rainbow', dropna= False)
g.map_diag(plt.hist)
g.map_upper(plt.scatter)
g.map_lower(sns.kdeplot)

# %% [markdown]
# Description:
